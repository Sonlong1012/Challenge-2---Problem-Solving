# %%
def find_missing_number(arr):
    n = len(arr)
    total_sum = (n + 1) * (n + 2) // 2
    array_sum = sum(arr)
    missing_number = total_sum - array_sum
    return missing_number


input_array = [3, 7, 1, 2, 6, 4]
print("The missing number is:", find_missing_number(input_array))
# Out:
# The missing number is: 5
